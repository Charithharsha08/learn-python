# %%
import requests
import json

resources = requests.get('https://api.github.com/events')
print(resources)
print(resources.status_code)

if resources.status_code == 200:
    print('success')
    print()
    print(resources.url)
    print()
    print(resources.headers)
    print()
    print(resources.headers['content-type'])

else:
    print('failed to retrieve data. Status code:', resources.status_code)
# Out:
# <Response [200]>
# 200
# success
#
# https://api.github.com/events
#
# ...

# %%
import requests
import json

resources = requests.get('https://api.github.com/events')
print(resources)
print(resources.status_code)

if resources.status_code == 200:
   
    print(resources.text)
    print(type(resources.text))
    print()
    print(resources.json())
    print(type(resources.json()))
else:
    print('failed to retrieve data. Status code:', resources.status_code)
# Out:
# <Response [200]>
# 200
# ...

# %%
import requests
import json

response = requests.get('https://api.github.com/events')

if response.status_code == 200:
    print('success')
    print(response.headers['Content-Type'])


    if 'application/json' in response.headers.get('Content-Type', ''):
        data = response.json()
        print(data)
    else:
        print("Content type is not application/json")

    print(response.text)
else:
    print('failed to retrieve data. Status code:', response.status_code)
# Out:
# success
# application/json; charset=utf-8
# ...

# %%
import requests
import json

url = 'https://httpbin.org/post'
data = {
    "name": "John Doe",
    "age": 30,
    "isStudent": False,
    "hobbies": ["reading", "gardening", "swimming"]
}
headers = {
    "Content-Type": "application/json"
}

response = requests.post(url, data=data, headers=headers)
if response.status_code == 200:
    print('success')
    print(response.headers['Content-Type'])
    print(response.text)
else:
    print('failed to retrieve data. Status code:', response.status_code)
# Out:
# success
# application/json
# {
#   "args": {},
#   "data": "name=John+Doe&age=30&isStudent=False&hobbies=reading&hobbies=gardening&hobbies=swimming",
#   "files": {},
#   "form": {},
#   "headers": {
#     "Accept": "*/*",
#     "Accept-Encoding": "gzip, deflate",
#     "Content-Length": "87",
#     "Content-Type": "application/json",
#     "Host": "httpbin.org",
#     "User-Agent": "python-requests/2.32.4",
#     "X-Amzn-Trace-Id": "Root=1-68806a5b-30360398667fed6f777e4a51"
#   },
#   "json": null,
#   "origin": "103.247.51.124",
#   "url": "https://httpbin.org/post"
# }

# %%
import requests

url = 'https://jsonplaceholder.typicode.com/posts'
params = {
    "userId": 1,
    "id": 1
    }

response = requests.post(url, params=params)
print(response.status_code)
print(response.text)
# Out:
# 201
# {
#   "id": 101
# }

# %%
import requests

url = 'https://httpbin.org/get'
username = 'charithharsha'
password = '1234'
response = requests.get(url, auth=(username, password))
print(response.status_code)
print(response.text)
# Out:
# 200
# {
#   "args": {},
#   "headers": {
#     "Accept": "*/*",
#     "Accept-Encoding": "gzip, deflate",
#     "Authorization": "Basic Y2hhcml0aGhhcnNoYToxMjM0",
#     "Host": "httpbin.org",
#     "User-Agent": "python-requests/2.32.4",
#     "X-Amzn-Trace-Id": "Root=1-6880715f-14a822355690feb11d3ea146"
#   },
#   "origin": "175.157.241.106",
#   "url": "https://httpbin.org/get"
# }
